# %%
# Import all the required Python Libraries.
import numpy as np
import pandas as pd

# %%
#Collect the dataset from kaggle.com

#Load the Dataset into pandas data frame
data_frame=pd.read_csv("D:/study/DSBDA/DSBDA Pratham/ipynb code DS/Data Wrankling 2/AcademicPerformance.csv")
data_frame
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 0        M          KW       KuwaIT    lowerlevel    G-04         A
# 1        M          KW       KuwaIT    lowerlevel    G-04       NaN
# 2        M          KW       KuwaIT    lowerlevel    G-04         A
# 3      NaN          KW       KuwaIT    lowerlevel    G-04         A
# 4        M          KW       KuwaIT    lowerlevel    G-04         A
# ..     ...         ...          ...           ...     ...       ...
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 0           IT        F   Father         15.0              16.0
# ...

# %%
#Step-I
#Scan all variables for missing values and inconsistencies. If there are missing values and/or inconsistencies, 
#use any of the suitable techniques to deal with them
data_frame.head()
# Out:
#   gender NationalITy PlaceofBirth     StageID GradeID SectionID Topic  \
# 0      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 1      M          KW       KuwaIT  lowerlevel    G-04       NaN    IT
# 2      M          KW       KuwaIT  lowerlevel    G-04         A    IT
# 3    NaN          KW       KuwaIT  lowerlevel    G-04         A    IT
# 4      M          KW       KuwaIT  lowerlevel    G-04         A    IT
#
#   Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0        F   Father         15.0              16.0                2.0
# 1        F   Father         20.0              20.0                3.0
# 2      NaN   Father         10.0               7.0                0.0
# 3        F   Father         30.0              25.0                5.0
# 4        F   Father         40.0              50.0               12.0
#
#    Discussion ParentAnsweringSurvey ParentschoolSatisfaction  \
# ...

# %%
data_frame.tail()
# Out:
#     gender NationalITy PlaceofBirth       StageID GradeID SectionID  \
# 475      F      Jordan       Jordan  MiddleSchool    G-08         A
# 476      F      Jordan       Jordan  MiddleSchool    G-08         A
# 477      F      Jordan       Jordan  MiddleSchool    G-08         A
# 478      F      Jordan       Jordan  MiddleSchool    G-08         A
# 479      F      Jordan       Jordan  MiddleSchool    G-08         A
#
#          Topic Semester Relation  raisedhands  VisITedResources  \
# 475  Chemistry        S   Father          5.0               4.0
# 476    Geology        F   Father         50.0              77.0
# 477    Geology        S   Father         55.0              74.0
# 478    History        F   Father         30.0              17.0
# 479    History        S   Father         35.0              14.0
#
#      AnnouncementsView  Discussion ParentAnsweringSurvey  \
# 475                5.0           8                    No
# ...

# %%
data_frame.describe()
# Out:
#        raisedhands  VisITedResources  AnnouncementsView  Discussion
# count   470.000000        475.000000         476.000000  480.000000
# mean     47.506383         55.374737          38.237395   43.283333
# std      30.483226         32.769213          26.493621   27.637735
# min       0.000000          0.000000           0.000000    1.000000
# 25%      17.000000         20.000000          15.000000   20.000000
# 50%      50.000000         66.000000          33.000000   39.000000
# 75%      75.000000         84.000000          58.000000   70.000000
# max     100.000000         99.000000          98.000000   99.000000

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    470 non-null    object
#  1   NationalITy               480 non-null    object
#  2   PlaceofBirth              480 non-null    object
#  3   StageID                   480 non-null    object
#  4   GradeID                   480 non-null    object
#  5   SectionID                 474 non-null    object
#  6   Topic                     480 non-null    object
#  7   Semester                  471 non-null    object
#  8   Relation                  480 non-null    object
#  9   raisedhands               470 non-null    float64
#  10  VisITedResources          475 non-null    float64
#  11  AnnouncementsView         476 non-null    float64
#  12  Discussion                480 non-null    int64
# ...

# %%
data_frame.shape
# Out:
# (480, 17)

# %%
data_frame.isnull()
# Out:
#      gender  NationalITy  PlaceofBirth  StageID  GradeID  SectionID  Topic  \
# 0     False        False         False    False    False      False  False
# 1     False        False         False    False    False       True  False
# 2     False        False         False    False    False      False  False
# 3      True        False         False    False    False      False  False
# 4     False        False         False    False    False      False  False
# ..      ...          ...           ...      ...      ...        ...    ...
# 475   False        False         False    False    False      False  False
# 476   False        False         False    False    False      False  False
# 477   False        False         False    False    False      False  False
# 478   False        False         False    False    False      False  False
# 479   False        False         False    False    False      False  False
#
# ...

# %%
data_frame.isnull().any()
# Out:
# gender                       True
# NationalITy                 False
# PlaceofBirth                False
# StageID                     False
# GradeID                     False
# SectionID                    True
# Topic                       False
# Semester                     True
# Relation                    False
# raisedhands                  True
# VisITedResources             True
# AnnouncementsView            True
# Discussion                  False
# ParentAnsweringSurvey       False
# ParentschoolSatisfaction    False
# StudentAbsenceDays          False
# Class                       False
# dtype: bool

# %%
data_frame.isnull().any().any()
# Out:
# True

# %%
data_frame.isnull().sum()
# Out:
# gender                      10
# NationalITy                  0
# PlaceofBirth                 0
# StageID                      0
# GradeID                      0
# SectionID                    6
# Topic                        0
# Semester                     9
# Relation                     0
# raisedhands                 10
# VisITedResources             5
# AnnouncementsView            4
# Discussion                   0
# ParentAnsweringSurvey        0
# ParentschoolSatisfaction     0
# StudentAbsenceDays           0
# Class                        0
# dtype: int64

# %%
data_frame["Discussion"].std()
# Out:
# 27.63773503837636

# %%
data_frame["VisITedResources"].replace(np.NaN, inplace=True)

# %%
data_frame.isnull().sum()
# Out:
# gender                      10
# NationalITy                  0
# PlaceofBirth                 0
# StageID                      0
# GradeID                      0
# SectionID                    6
# Topic                        0
# Semester                     9
# Relation                     0
# raisedhands                 10
# VisITedResources             0
# AnnouncementsView            4
# Discussion                   0
# ParentAnsweringSurvey        0
# ParentschoolSatisfaction     0
# StudentAbsenceDays           0
# Class                        0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
x = data_frame['raisedhands']
y = data_frame['Discussion']
sns.regplot(x , y)
# Out:
# c:\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='raisedhands', ylabel='Discussion'>

# %%
sns.boxplot(x,y)
# Out:
# <AxesSubplot:xlabel='raisedhands', ylabel='Discussion'>

# %%
from scipy import stats

z = np.abs(stats.zscore(data_frame['AnnouncementsView']))
z
threshold = 3
np.where(z > 3)
# Out:
# (array([], dtype=int64),)

# %%
#Step-III
#3.	Apply data transformations on at least one of the variables

df = pd.DataFrame({
    'Income': [15000, 1800, 120000, 10000],
    'Age': [25, 18, 42, 51],
    'Department': ['HR','Legal','Marketing','Management']
})
df
# Out:
#    Income  Age  Department
# 0   15000   25          HR
# 1    1800   18       Legal
# 2  120000   42   Marketing
# 3   10000   51  Management

# %%
cp = df.copy()

# %%
cp
# Out:
#    Income  Age  Department
# 0   15000   25          HR
# 1    1800   18       Legal
# 2  120000   42   Marketing
# 3   10000   51  Management

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
col_names = ['Income', 'Age']
features = cp[col_names]


cp[col_names] = scaler.fit_transform(features.values)

cp[col_names]
# features.values
# Out:
#      Income       Age
# 0  0.111675  0.212121
# 1  0.000000  0.000000
# 2  1.000000  0.727273
# 3  0.069374  1.000000

# %%
cp
# Out:
#      Income       Age  Department
# 0  0.111675  0.212121          HR
# 1  0.000000  0.000000       Legal
# 2  1.000000  0.727273   Marketing
# 3  0.069374  1.000000  Management

# %%
df
# Out:
#    Income  Age  Department
# 0   15000   25          HR
# 1    1800   18       Legal
# 2  120000   42   Marketing
# 3   10000   51  Management
